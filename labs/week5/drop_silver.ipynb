-- %% [markdown]
-- # Drop Silver Schema and Tables

-- %% [markdown]
-- ## Setup: Set Your Catalog
--
-- **IMPORTANT:** Before running any queries, set your assigned catalog name.

-- %%
-- TODO: Replace with your assigned catalog name
USE CATALOG hwestudent50;

-- %%
-- TODO: Drop the silver.order_items table
drop table if exists silver.order_items

-- %%
-- TODO: Drop the silver.orders table
drop table if exists silver.orders

-- %%
-- TODO: Drop the silver.customers table
drop table if exists silver.customers

-- %%
-- TODO: Drop the silver.stores table
drop table if exists silver.stores

-- %%
-- TODO: Drop the silver.books table
drop table if exists silver.books

-- %%
-- TODO: Drop the silver.categories table
drop table if exists silver.categories

-- %%
-- TODO: Drop the silver schema (use CASCADE to drop all tables)
drop schema if exists silver cascade
